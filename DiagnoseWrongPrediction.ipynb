# %%
from train import train_paths, train_labels, convert_int_text, df_real_train, df_kanku, df_gen
import pandas

# %%
df = pandas.DataFrame({'path':train_paths, 'labels':train_labels})
df = df[['path', 'labels']]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-91f795dc4887> in <module>
#       1 df = pandas.DataFrame({'path':train_paths, 'labels':train_labels})
# ----> 2 df['text'] = df['labels'].map(lambda x: convert_int_text(x))
#       3 df = df[['path', 'labels']]
#
# /miniconda/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2996         """
#    2997         new_values = super(Series, self)._map_values(
# -> 2998             arg, na_action=na_action)
#    2999         return self._constructor(new_values,
#    3000                                  index=self.index).__finalize__(self)
#
# /miniconda/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
# ...

# %%
from pyson.utils import show_df

# %%
df_sample = df_gen.sample(10)#['labels'].map(lambda x: convert_int_text(x))
# df_sample['text'] = df_sample['text'].map(lambda x: ''.join(convert_int_text(x)))
df_sample = df_sample[['path', 'text']]
show_df(df_sample, 'path')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>path</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>221054</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>真性未血球増加定・脱水症・下痢・嘱吐・火傷・慢性心肺痍患</td>
#     </tr>
#     <tr>
#       <th>321924</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>検出せず</td>
#     </tr>
#     <tr>
#       <th>2853</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>LDH(*)</td>
#     </tr>
#     <tr>
#       <th>115449</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>健康診断受診日</td>
#     </tr>
#     <tr>
#       <th>334378</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>95.9cm</td>
#     </tr>
#     <tr>
#       <th>15142</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>評</td>
#     </tr>
#     <tr>
#       <th>152163</th>
# ...
